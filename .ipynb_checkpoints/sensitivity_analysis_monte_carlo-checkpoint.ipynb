# %% [markdown]
# # Monte Carlo Analysis
#
# This notebook processes the results from multiple simulation runs. It scans all merged simulation outputs, extracts key metrics, and provides statistical summaries and visualizations.
#
# **Key Analyses**
# - Extracts peak adult population and timing from each run
# - Computes statistical summaries (mean, median, std, 95% CI)
# - Generates histograms and box plots of peak populations
# - Shows time series from representative runs
# - Produces a complete report with all findings
#
# **Assumptions**
# - Simulation outputs follow the naming pattern: `merged_snapshots_*.csv`
# - Each file contains adult population data across ticks
# - Ticks represent 15-minute time steps (96 ticks per day)

# %%
import glob
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy.stats import spearmanr, t
from scipy.interpolate import RegularGridInterpolator
from sklearn.neighbors import KernelDensity
import warnings
warnings.filterwarnings('ignore')

# ======================================================================
# CONFIGURATION – EDIT THESE PATHS
# ======================================================================
MONTE_CARLO_DIR = "/mnt/monadworld/projects/phd/monte_carlo_results"
CHUNKSIZE = 100000
TICKS_PER_RUN = 17280  # Total ticks per simulation

# Output paths
OUTPUT_CSV = os.path.join(MONTE_CARLO_DIR, 'monte_carlo_peak_analysis.csv')
OUTPUT_PEAK_PNG = os.path.join(MONTE_CARLO_DIR, 'monte_carlo_peak_analysis.png')
OUTPUT_TIMESERIES_PNG = os.path.join(MONTE_CARLO_DIR, 'monte_carlo_time_series.png')
OUTPUT_REPORT = os.path.join(MONTE_CARLO_DIR, 'monte_carlo_complete_report.txt')

os.makedirs(MONTE_CARLO_DIR, exist_ok=True)

# %% [markdown]
# ## 1. Core Analysis Functions

# %%
# ----------------------------------------------------------------------
# Helper Functions
# ----------------------------------------------------------------------
def find_merged_files(base_dir):
    """Find all merged simulation output files in the Monte Carlo directory."""
    pattern = os.path.join(base_dir, "seed_*", "merged_*.csv")
    files = glob.glob(pattern)
    print(f"Found {len(files)} merged files")
    return files


def analyze_tick_distribution(filepath, chunksize=CHUNKSIZE):
    """
    Analyze adult distribution across all ticks in a run.
    Returns the tick with maximum adults and the peak adult count.
    """
    try:
        print(f"  Analyzing: {os.path.basename(filepath)}")
        
        # Track adults by tick
        adult_by_tick = {}
        total_adults = 0
        max_tick = 0
        
        # Process file in chunks
        for chunk in pd.read_csv(filepath, 
                                 usecols=['TickCount', 'AgentType', 'Stage'], 
                                 chunksize=chunksize, 
                                 low_memory=False):
            
            # Filter for adult LivingAgents
            mask = (chunk['AgentType'] == 'LivingAgent') & (chunk['Stage'] == 'ADULT')
            adults = chunk[mask]
            
            if not adults.empty:
                # Count adults per tick
                tick_counts = adults['TickCount'].value_counts()
                for tick, count in tick_counts.items():
                    adult_by_tick[tick] = adult_by_tick.get(tick, 0) + count
                    total_adults += count
                    if tick > max_tick:
                        max_tick = tick
        
        # Find peak tick (maximum adults)
        if adult_by_tick:
            peak_tick = max(adult_by_tick, key=adult_by_tick.get)
            peak_adults = adult_by_tick[peak_tick]
            
            # Get adults at final tick
            final_adults = adult_by_tick.get(max_tick, 0)
            
            # Get adults at tick 100 (early stage) if available
            early_adults = adult_by_tick.get(100, 0)
            
            print(f"  Total adults across all ticks: {total_adults:,}")
            print(f"  Peak tick: {peak_tick} with {peak_adults:,} adults")
            print(f"  Final tick ({max_tick}): {final_adults:,} adults")
            if early_adults > 0:
                print(f"  Tick 100: {early_adults:,} adults")
            
            return {
                'file': os.path.basename(filepath),
                'peak_tick': peak_tick,
                'peak_adults': peak_adults,
                'final_tick': max_tick,
                'final_adults': final_adults,
                'early_adults': early_adults,
                'total_adults': total_adults,
                'ticks_with_adults': len(adult_by_tick)
            }
        else:
            print("  No adults found in this file!")
            return None
            
    except Exception as e:
        print(f"  Error: {e}")
        return None


def get_time_series(filepath, chunksize=CHUNKSIZE):
    """
    Get the full adult population time series for a run.
    """
    try:
        adult_series = {}
        
        for chunk in pd.read_csv(filepath, 
                                 usecols=['TickCount', 'AgentType', 'Stage'], 
                                 chunksize=chunksize, 
                                 low_memory=False):
            
            mask = (chunk['AgentType'] == 'LivingAgent') & (chunk['Stage'] == 'ADULT')
            adults = chunk[mask]
            
            if not adults.empty:
                tick_counts = adults['TickCount'].value_counts()
                for tick, count in tick_counts.items():
                    adult_series[tick] = adult_series.get(tick, 0) + count
        
        if adult_series:
            df_series = pd.DataFrame({
                'tick': sorted(adult_series.keys()),
                'adults': [adult_series[t] for t in sorted(adult_series.keys())]
            })
            return df_series
        else:
            return pd.DataFrame(columns=['tick', 'adults'])
            
    except Exception as e:
        print(f"  Error getting time series: {e}")
        return pd.DataFrame(columns=['tick', 'adults'])

# %% [markdown]
# ## 2. Run Analysis
#
# Process all Monte Carlo output files and extract key metrics.

# %%
print("="*60)
print("MONTE CARLO ANALYSIS - PEAK ADULT POPULATION")
print("="*60)

merged_files = find_merged_files(MONTE_CARLO_DIR)

results = []
for i, filepath in enumerate(merged_files):
    print(f"\n[{i+1}/{len(merged_files)}] {os.path.basename(filepath)}")
    result = analyze_tick_distribution(filepath)
    if result:
        results.append(result)

if not results:
    raise RuntimeError("❌ No results were produced!")

df_results = pd.DataFrame(results)
df_results.to_csv(OUTPUT_CSV, index=False)
print(f"\n✅ Results saved to: {OUTPUT_CSV}")
# Out:
# ============================================================
# MONTE CARLO ANALYSIS - PEAK ADULT POPULATION
# ============================================================
# Found 67 merged files
#
# [1/67] merged_snapshots_20260822_144559.csv
#   Analyzing: merged_snapshots_20260822_144559.csv
#   Total adults across all ticks: 108,648
#   Peak tick: 100 with 5,935 adults
#   Final tick (6500): 3 adults
#   Tick 100: 5,935 adults
#
# [2/67] merged_snapshots_20260823_052943.csv
#   Analyzing: merged_snapshots_20260823_052943.csv
#   Total adults across all ticks: 146,350
#   Peak tick: 100 with 4,896 adults
#   Final tick (9300): 1 adults
#   Tick 100: 4,896 adults
#
# [3/67] merged_snapshots_20260822_094011.csv
#   Analyzing: merged_snapshots_20260822_094011.csv
#   Total adults across all ticks: 150,906
#   Peak tick: 100 with 5,968 adults
#   Final tick (7900): 1 adults
#   Tick 100: 5,968 adults
#
# [4/67] merged_snapshots_20260823_013658.csv
#   Analyzing: merged_snapshots_20260823_013658.csv
#   Total adults across all ticks: 180,283
#   Peak tick: 100 with 6,944 adults
#   Final tick (8600): 2 adults
#   Tick 100: 6,944 adults
#
# [5/67] merged_snapshots_20260823_022952.csv
#   Analyzing: merged_snapshots_20260823_022952.csv
#   Total adults across all ticks: 239,412
#   Peak tick: 100 with 7,623 adults
#   Final tick (8300): 1 adults
#   Tick 100: 7,623 adults
#
# [6/67] merged_snapshots_20260822_105532.csv
#   Analyzing: merged_snapshots_20260822_105532.csv
#   Total adults across all ticks: 179,405
#   Peak tick: 100 with 5,948 adults
#   Final tick (9200): 1 adults
#   Tick 100: 5,948 adults
#
# [7/67] merged_snapshots_20260822_120702.csv
#   Analyzing: merged_snapshots_20260822_120702.csv
#   Total adults across all ticks: 103,731
#   Peak tick: 100 with 5,952 adults
#   Final tick (5800): 1 adults
#   Tick 100: 5,952 adults
#
# [8/67] merged_snapshots_20260823_014955.csv
#   Analyzing: merged_snapshots_20260823_014955.csv
#   Total adults across all ticks: 194,594
#   Peak tick: 100 with 8,799 adults
#   Final tick (6900): 2 adults
#   Tick 100: 8,799 adults
#
# [9/67] merged_snapshots_20260823_024242.csv
#   Analyzing: merged_snapshots_20260823_024242.csv
#   Total adults across all ticks: 141,557
#   Peak tick: 100 with 6,968 adults
#   Final tick (6900): 1 adults
#   Tick 100: 6,968 adults
#
# [10/67] merged_snapshots_20260822_111427.csv
#   Analyzing: merged_snapshots_20260822_111427.csv
#   Total adults across all ticks: 199,452
#   Peak tick: 100 with 5,885 adults
#   Final tick (9500): 2 adults
#   Tick 100: 5,885 adults
#
# [11/67] merged_snapshots_20260822_121847.csv
#   Analyzing: merged_snapshots_20260822_121847.csv
#   Total adults across all ticks: 90,634
#   Peak tick: 100 with 5,834 adults
#   Final tick (5600): 2 adults
#   Tick 100: 5,834 adults
#
# [12/67] merged_snapshots_20260823_025444.csv
#   Analyzing: merged_snapshots_20260823_025444.csv
#   Total adults across all ticks: 87,220
#   Peak tick: 100 with 5,235 adults
#   Final tick (6000): 1 adults
#   Tick 100: 5,235 adults
#
# [13/67] merged_snapshots_20260822_113046.csv
#   Analyzing: merged_snapshots_20260822_113046.csv
#   Total adults across all ticks: 165,829
#   Peak tick: 100 with 6,023 adults
#   Final tick (8800): 1 adults
#   Tick 100: 6,023 adults
#
# [14/67] merged_snapshots_20260822_123044.csv
#   Analyzing: merged_snapshots_20260822_123044.csv
#   Total adults across all ticks: 96,627
#   Peak tick: 100 with 5,997 adults
#   Final tick (5900): 2 adults
#   Tick 100: 5,997 adults
#
# [15/67] merged_snapshots_20260823_030525.csv
#   Analyzing: merged_snapshots_20260823_030525.csv
#   Total adults across all ticks: 73,828
#   Peak tick: 100 with 5,382 adults
#   Final tick (5900): 1 adults
#   Tick 100: 5,382 adults
#
# [16/67] merged_snapshots_20260822_114912.csv
#   Analyzing: merged_snapshots_20260822_114912.csv
#   Total adults across all ticks: 192,983
#   Peak tick: 100 with 5,946 adults
#   Final tick (9300): 1 adults
#   Tick 100: 5,946 adults
#
# [17/67] merged_snapshots_20260822_124419.csv
#   Analyzing: merged_snapshots_20260822_124419.csv
#   Total adults across all ticks: 124,171
#   Peak tick: 100 with 5,931 adults
#   Final tick (7200): 1 adults
#   Tick 100: 5,931 adults
#
# [18/67] merged_snapshots_20260823_031615.csv
#   Analyzing: merged_snapshots_20260823_031615.csv
#   Total adults across all ticks: 45,366
#   Peak tick: 100 with 4,100 adults
#   Final tick (4600): 1 adults
#   Tick 100: 4,100 adults
#
# [19/67] merged_snapshots_20260822_125856.csv
#   Analyzing: merged_snapshots_20260822_125856.csv
#   Total adults across all ticks: 143,730
#   Peak tick: 100 with 5,963 adults
#   Final tick (7500): 1 adults
#   Tick 100: 5,963 adults
#
# [20/67] merged_snapshots_20260823_033417.csv
#   Analyzing: merged_snapshots_20260823_033417.csv
#   Total adults across all ticks: 305,028
#   Peak tick: 100 with 8,578 adults
#   Final tick (9000): 3 adults
#   Tick 100: 8,578 adults
#
# [21/67] merged_snapshots_20260822_131322.csv
#   Analyzing: merged_snapshots_20260822_131322.csv
#   Total adults across all ticks: 132,245
#   Peak tick: 100 with 5,955 adults
#   Final tick (7100): 2 adults
#   Tick 100: 5,955 adults
#
# [22/67] merged_snapshots_20260823_034727.csv
#   Analyzing: merged_snapshots_20260823_034727.csv
#   Total adults across all ticks: 89,490
#   Peak tick: 100 with 5,121 adults
#   Final tick (6700): 1 adults
#   Tick 100: 5,121 adults
#
# [23/67] merged_snapshots_20260822_132719.csv
#   Analyzing: merged_snapshots_20260822_132719.csv
#   Total adults across all ticks: 129,630
#   Peak tick: 100 with 5,933 adults
#   Final tick (6800): 2 adults
#   Tick 100: 5,933 adults
#
# [24/67] merged_snapshots_20260823_040039.csv
#   Analyzing: merged_snapshots_20260823_040039.csv
#   Total adults across all ticks: 186,902
#   Peak tick: 100 with 8,717 adults
#   Final tick (6000): 3 adults
#   Tick 100: 8,717 adults
#
# [25/67] merged_snapshots_20260822_134055.csv
#   Analyzing: merged_snapshots_20260822_134055.csv
#   Total adults across all ticks: 122,187
#   Peak tick: 100 with 5,889 adults
#   Final tick (6900): 1 adults
#   Tick 100: 5,889 adults
#
# [26/67] merged_snapshots_20260823_040943.csv
#   Analyzing: merged_snapshots_20260823_040943.csv
#   Total adults across all ticks: 38,996
#   Peak tick: 100 with 4,610 adults
#   Final tick (3500): 1 adults
#   Tick 100: 4,610 adults
#
# [27/67] merged_snapshots_20260822_135417.csv
#   Analyzing: merged_snapshots_20260822_135417.csv
#   Total adults across all ticks: 121,101
#   Peak tick: 100 with 6,012 adults
#   Final tick (6900): 1 adults
#   Tick 100: 6,012 adults
#
# [28/67] merged_snapshots_20260823_042616.csv
#   Analyzing: merged_snapshots_20260823_042616.csv
#   Total adults across all ticks: 112,822
#   Peak tick: 100 with 4,651 adults
#   Final tick (8600): 1 adults
#   Tick 100: 4,651 adults
#
# [29/67] merged_snapshots_20260822_140750.csv
#   Analyzing: merged_snapshots_20260822_140750.csv
#   Total adults across all ticks: 124,006
#   Peak tick: 100 with 5,992 adults
#   Final tick (6900): 2 adults
#   Tick 100: 5,992 adults
#
# [30/67] merged_snapshots_20260823_043829.csv
#   Analyzing: merged_snapshots_20260823_043829.csv
#   Total adults across all ticks: 78,504
#   Peak tick: 100 with 4,615 adults
#   Final tick (5900): 1 adults
#   Tick 100: 4,615 adults
#
# [31/67] merged_snapshots_20260822_142044.csv
#   Analyzing: merged_snapshots_20260822_142044.csv
#   Total adults across all ticks: 112,509
#   Peak tick: 100 with 5,878 adults
#   Final tick (6300): 1 adults
#   Tick 100: 5,878 adults
#
# [32/67] merged_snapshots_20260823_045716.csv
#   Analyzing: merged_snapshots_20260823_045716.csv
#   Total adults across all ticks: 252,592
#   Peak tick: 100 with 7,714 adults
#   Final tick (8600): 1 adults
#   Tick 100: 7,714 adults
#
# [33/67] merged_snapshots_20260822_143311.csv
#   Analyzing: merged_snapshots_20260822_143311.csv
#   Total adults across all ticks: 109,562
#   Peak tick: 100 with 5,958 adults
#   Final tick (6600): 1 adults
#   Tick 100: 5,958 adults
#
# [34/67] merged_snapshots_20260823_051117.csv
#   Analyzing: merged_snapshots_20260823_051117.csv
#   Total adults across all ticks: 70,730
#   Peak tick: 100 with 3,525 adults
#   Final tick (7000): 1 adults
#   Tick 100: 3,525 adults
#
# [35/67] merged_snapshots_20260822_145839.csv
#   Analyzing: merged_snapshots_20260822_145839.csv
#   Total adults across all ticks: 109,281
#   Peak tick: 100 with 6,003 adults
#   Final tick (6700): 1 adults
#   Tick 100: 6,003 adults
#
# [36/67] merged_snapshots_20260823_054312.csv
#   Analyzing: merged_snapshots_20260823_054312.csv
#   Total adults across all ticks: 112,375
#   Peak tick: 100 with 5,783 adults
#   Final tick (6200): 1 adults
#   Tick 100: 5,783 adults
#
# [37/67] merged_snapshots_20260822_151101.csv
#   Analyzing: merged_snapshots_20260822_151101.csv
#   Total adults across all ticks: 105,852
#   Peak tick: 100 with 5,906 adults
#   Final tick (6200): 1 adults
#   Tick 100: 5,906 adults
#
# [38/67] merged_snapshots_20260823_055920.csv
#   Analyzing: merged_snapshots_20260823_055920.csv
#   Total adults across all ticks: 217,564
#   Peak tick: 100 with 7,768 adults
#   Final tick (9300): 1 adults
#   Tick 100: 7,768 adults
#
# [39/67] merged_snapshots_20260822_152345.csv
#   Analyzing: merged_snapshots_20260822_152345.csv
#   Total adults across all ticks: 111,317
#   Peak tick: 100 with 5,995 adults
#   Final tick (6500): 1 adults
#   Tick 100: 5,995 adults
#
# [40/67] merged_snapshots_20260823_061723.csv
#   Analyzing: merged_snapshots_20260823_061723.csv
#   Total adults across all ticks: 217,220
#   Peak tick: 100 with 7,119 adults
#   Final tick (9100): 1 adults
#   Tick 100: 7,119 adults
#
# [41/67] merged_snapshots_20260822_153612.csv
#   Analyzing: merged_snapshots_20260822_153612.csv
#   Total adults across all ticks: 109,266
#   Peak tick: 100 with 5,987 adults
#   Final tick (6200): 1 adults
#   Tick 100: 5,987 adults
#
# [42/67] merged_snapshots_20260823_062752.csv
#   Analyzing: merged_snapshots_20260823_062752.csv
#   Total adults across all ticks: 37,407
#   Peak tick: 100 with 3,993 adults
#   Final tick (4600): 2 adults
#   Tick 100: 3,993 adults
#
# [43/67] merged_snapshots_20260822_154922.csv
#   Analyzing: merged_snapshots_20260822_154922.csv
#   Total adults across all ticks: 122,938
#   Peak tick: 100 with 6,041 adults
#   Final tick (6900): 1 adults
#   Tick 100: 6,041 adults
#
# [44/67] merged_snapshots_20260823_070027.csv
#   Analyzing: merged_snapshots_20260823_070027.csv
#   Total adults across all ticks: 491,648
#   Peak tick: 100 with 7,844 adults
#   Final tick (17000): 1 adults
#   Tick 100: 7,844 adults
#
# [45/67] merged_snapshots_20260822_160220.csv
#   Analyzing: merged_snapshots_20260822_160220.csv
#   Total adults across all ticks: 111,558
#   Peak tick: 100 with 6,034 adults
#   Final tick (6500): 1 adults
#   Tick 100: 6,034 adults
#
# [46/67] merged_snapshots_20260823_072005.csv
#   Analyzing: merged_snapshots_20260823_072005.csv
#   Total adults across all ticks: 274,970
#   Peak tick: 100 with 6,592 adults
#   Final tick (9800): 1 adults
#   Tick 100: 6,592 adults
#
# [47/67] merged_snapshots_20260822_161507.csv
#   Analyzing: merged_snapshots_20260822_161507.csv
#   Total adults across all ticks: 114,692
#   Peak tick: 100 with 6,005 adults
#   Final tick (6300): 1 adults
#   Tick 100: 6,005 adults
#
# [48/67] merged_snapshots_20260823_073804.csv
#   Analyzing: merged_snapshots_20260823_073804.csv
#   Total adults across all ticks: 291,478
#   Peak tick: 100 with 8,645 adults
#   Final tick (9500): 2 adults
#   Tick 100: 8,645 adults
#
# [49/67] merged_snapshots_20260822_162711.csv
#   Analyzing: merged_snapshots_20260822_162711.csv
#   Total adults across all ticks: 98,009
#   Peak tick: 100 with 5,917 adults
#   Final tick (6100): 1 adults
#   Tick 100: 5,917 adults
#
# [50/67] merged_snapshots_20260823_075102.csv
#   Analyzing: merged_snapshots_20260823_075102.csv
#   Total adults across all ticks: 84,671
#   Peak tick: 100 with 4,714 adults
#   Final tick (7100): 2 adults
#   Tick 100: 4,714 adults
#
# [51/67] merged_snapshots_20260822_163913.csv
#   Analyzing: merged_snapshots_20260822_163913.csv
#   Total adults across all ticks: 98,757
#   Peak tick: 100 with 5,926 adults
#   Final tick (6200): 1 adults
#   Tick 100: 5,926 adults
#
# [52/67] merged_snapshots_20260823_080355.csv
#   Analyzing: merged_snapshots_20260823_080355.csv
#   Total adults across all ticks: 121,443
#   Peak tick: 100 with 6,030 adults
#   Final tick (6300): 1 adults
#   Tick 100: 6,030 adults
#
# [53/67] merged_snapshots_20260822_165108.csv
#   Analyzing: merged_snapshots_20260822_165108.csv
#   Total adults across all ticks: 98,694
#   Peak tick: 100 with 6,021 adults
#   Final tick (6100): 1 adults
#   Tick 100: 6,021 adults
#
# [54/67] merged_snapshots_20260823_082000.csv
#   Analyzing: merged_snapshots_20260823_082000.csv
#   Total adults across all ticks: 229,618
#   Peak tick: 100 with 7,790 adults
#   Final tick (8000): 1 adults
#   Tick 100: 7,790 adults
#
# [55/67] merged_snapshots_20260822_170249.csv
#   Analyzing: merged_snapshots_20260822_170249.csv
#   Total adults across all ticks: 97,011
#   Peak tick: 100 with 6,007 adults
#   Final tick (5800): 2 adults
#   Tick 100: 6,007 adults
#
# [56/67] merged_snapshots_20260823_083023.csv
#   Analyzing: merged_snapshots_20260823_083023.csv
#   Total adults across all ticks: 32,006
#   Peak tick: 100 with 3,173 adults
#   Final tick (5100): 2 adults
#   Tick 100: 3,173 adults
#
# [57/67] merged_snapshots_20260822_171431.csv
#   Analyzing: merged_snapshots_20260822_171431.csv
#   Total adults across all ticks: 94,660
#   Peak tick: 100 with 6,017 adults
#   Final tick (5800): 1 adults
#   Tick 100: 6,017 adults
#
# [58/67] merged_snapshots_20260823_084613.csv
#   Analyzing: merged_snapshots_20260823_084613.csv
#   Total adults across all ticks: 225,303
#   Peak tick: 100 with 8,222 adults
#   Final tick (9200): 1 adults
#   Tick 100: 8,222 adults
#
# [59/67] merged_snapshots_20260822_172640.csv
#   Analyzing: merged_snapshots_20260822_172640.csv
#   Total adults across all ticks: 104,059
#   Peak tick: 100 with 5,941 adults
#   Final tick (6100): 1 adults
#   Tick 100: 5,941 adults
#
# [60/67] merged_snapshots_20260823_090211.csv
#   Analyzing: merged_snapshots_20260823_090211.csv
#   Total adults across all ticks: 233,220
#   Peak tick: 100 with 7,948 adults
#   Final tick (7600): 2 adults
#   Tick 100: 7,948 adults
#
# [61/67] merged_snapshots_20260822_173841.csv
#   Analyzing: merged_snapshots_20260822_173841.csv
#   Total adults across all ticks: 99,495
#   Peak tick: 100 with 5,952 adults
#   Final tick (6100): 1 adults
#   Tick 100: 5,952 adults
#
# [62/67] merged_snapshots_20260823_092228.csv
#   Analyzing: merged_snapshots_20260823_092228.csv
#   Total adults across all ticks: 338,585
#   Peak tick: 100 with 8,196 adults
#   Final tick (11500): 2 adults
#   Tick 100: 8,196 adults
#
# [63/67] merged_snapshots_20260822_175030.csv
#   Analyzing: merged_snapshots_20260822_175030.csv
#   Total adults across all ticks: 98,231
#   Peak tick: 100 with 6,024 adults
#   Final tick (5800): 1 adults
#   Tick 100: 6,024 adults
#
# [64/67] merged_snapshots_20260823_094041.csv
#   Analyzing: merged_snapshots_20260823_094041.csv
#   Total adults across all ticks: 293,554
#   Peak tick: 100 with 8,487 adults
#   Final tick (10100): 1 adults
#   Tick 100: 8,487 adults
#
# [65/67] merged_snapshots_20260822_180128.csv
#   Analyzing: merged_snapshots_20260822_180128.csv
#   Total adults across all ticks: 78,065
#   Peak tick: 100 with 5,911 adults
#   Final tick (5200): 1 adults
#   Tick 100: 5,911 adults
#
# [66/67] merged_snapshots_20260823_095458.csv
#   Analyzing: merged_snapshots_20260823_095458.csv
#   Total adults across all ticks: 154,457
#   Peak tick: 100 with 6,847 adults
#   Final tick (7700): 1 adults
#   Tick 100: 6,847 adults
#
# [67/67] merged_snapshots_20260822_181224.csv
#   Analyzing: merged_snapshots_20260822_181224.csv
#   Total adults across all ticks: 81,225
#   Peak tick: 100 with 5,993 adults
#   Final tick (5400): 1 adults
#   Tick 100: 5,993 adults
#
# ✅ Results saved to: /mnt/monadworld/projects/phd/monte_carlo_results/monte_carlo_peak_analysis.csv

# %% [markdown]
# ## 3. Summary Statistics

# %%
def compute_statistics(df_results):
    n = len(df_results)
    
    # Peak adults
    peak_mean = df_results['peak_adults'].mean()
    peak_std = df_results['peak_adults'].std()
    peak_median = df_results['peak_adults'].median()
    peak_min = df_results['peak_adults'].min()
    peak_max = df_results['peak_adults'].max()
    peak_range = peak_max - peak_min
    
    # 95% CI
    se = peak_std / np.sqrt(n)
    ci_low, ci_high = t.interval(0.95, n-1, loc=peak_mean, scale=se)
    
    # Peak tick
    tick_mean = df_results['peak_tick'].mean()
    tick_median = df_results['peak_tick'].median()
    tick_min = df_results['peak_tick'].min()
    tick_max = df_results['peak_tick'].max()
    
    # Final adults
    final_mean = df_results['final_adults'].mean()
    final_median = df_results['final_adults'].median()
    zero_final = (df_results['final_adults'] == 0).sum()
    
    # Early adults
    early_mean = df_results['early_adults'].mean()
    early_median = df_results['early_adults'].median()
    zero_early = (df_results['early_adults'] == 0).sum()
    
    stats = {
        'n': n,
        'peak_mean': peak_mean,
        'peak_std': peak_std,
        'peak_median': peak_median,
        'peak_min': peak_min,
        'peak_max': peak_max,
        'peak_range': peak_range,
        'ci_low': ci_low,
        'ci_high': ci_high,
        'tick_mean': tick_mean,
        'tick_median': tick_median,
        'tick_min': tick_min,
        'tick_max': tick_max,
        'final_mean': final_mean,
        'final_median': final_median,
        'zero_final': zero_final,
        'early_mean': early_mean,
        'early_median': early_median,
        'zero_early': zero_early,
    }
    return stats

stats = compute_statistics(df_results)

print("\n" + "="*60)
print("SUMMARY STATISTICS")
print("="*60)

print(f"\n📊 Peak Adult Population (maximum adults at any tick):")
print(f"  Mean: {stats['peak_mean']:,.0f} ± {stats['peak_std']:,.0f}")
print(f"  Median: {stats['peak_median']:,.0f}")
print(f"  95% CI: [{stats['ci_low']:,.0f}, {stats['ci_high']:,.0f}]")
print(f"  Min: {stats['peak_min']:,.0f}")
print(f"  Max: {stats['peak_max']:,.0f}")
print(f"  Range: {stats['peak_range']:,.0f}")

print(f"\n📈 Peak Timing:")
print(f"  Mean peak tick: {stats['tick_mean']:.0f}")
print(f"  Median peak tick: {stats['tick_median']:.0f}")
print(f"  Range: {stats['tick_min']:.0f} - {stats['tick_max']:.0f}")

print(f"\n📉 Population Stages:")
print(f"  Early (tick 100): {stats['early_mean']:,.0f} adults")
print(f"  Peak: {stats['peak_mean']:,.0f} adults")
print(f"  Final: {stats['final_mean']:,.0f} adults")
# Out:
# ============================================================
# SUMMARY STATISTICS
# ============================================================
#
# 📊 Peak Adult Population (maximum adults at any tick):
#   Mean: 6,199 ± 1,216
#   Median: 5,987
#   95% CI: [5,902, 6,495]
#   Min: 3,173
#   Max: 8,799
#   Range: 5,626
#
# 📈 Peak Timing:
#   Mean peak tick: 100
#   Median peak tick: 100
#   Range: 100 - 100
#
# 📉 Population Stages:
#   Early (tick 100): 6,199 adults
#   Peak: 6,199 adults
#   Final: 1 adults

# %% [markdown]
# ## 4. Visualizations
#
# Generate plots showing the distribution of peak populations, timing, and example time series.

# %%
def plot_peak_analysis(df_results, stats, output_path):
    fig, axes = plt.subplots(2, 2, figsize=(14, 10))
    
    # 1. Peak adult distribution
    ax = axes[0, 0]
    ax.hist(df_results['peak_adults'], bins=20, edgecolor='black', alpha=0.7, color='steelblue')
    ax.axvline(stats['peak_mean'], color='red', linestyle='--', label=f'Mean: {stats["peak_mean"]:,.0f}')
    ax.axvline(stats['peak_median'], color='green', linestyle='--', label=f'Median: {stats["peak_median"]:,.0f}')
    ax.set_xlabel('Peak Adult Count')
    ax.set_ylabel('Frequency')
    ax.set_title('Peak Adult Population Distribution')
    ax.legend()
    
    # 2. Peak tick distribution
    ax = axes[0, 1]
    ax.hist(df_results['peak_tick'], bins=20, edgecolor='black', alpha=0.7, color='coral')
    ax.axvline(stats['tick_mean'], color='red', linestyle='--', 
               label=f'Mean: {stats["tick_mean"]:.0f}')
    ax.set_xlabel('Tick Number')
    ax.set_ylabel('Frequency')
    ax.set_title('Peak Adult Tick Distribution')
    ax.legend()
    
    # 3. Peak vs Final adults
    ax = axes[1, 0]
    ax.scatter(df_results['peak_adults'], df_results['final_adults'], alpha=0.7)
    ax.plot([0, df_results['peak_adults'].max()], [0, df_results['peak_adults'].max()], 
            'r--', label='Peak = Final')
    ax.set_xlabel('Peak Adults')
    ax.set_ylabel('Final Adults')
    ax.set_title('Peak vs Final Adult Counts')
    ax.legend()
    
    # 4. Box plot comparison
    ax = axes[1, 1]
    data_to_plot = [df_results['peak_adults'], df_results['final_adults'], df_results['early_adults']]
    bp = ax.boxplot(data_to_plot, labels=['Peak', 'Final', 'Early'], patch_artist=True)
    for patch, color in zip(bp['boxes'], ['steelblue', 'coral', 'seagreen']):
        patch.set_facecolor(color)
    ax.set_ylabel('Adult Count')
    ax.set_title('Adult Population Comparison')
    ax.grid(True, alpha=0.3)
    
    plt.tight_layout()
    plt.savefig(output_path, dpi=300, bbox_inches='tight')
    plt.show()

plot_peak_analysis(df_results, stats, OUTPUT_PEAK_PNG)
print(f"✅ Figure saved to: {OUTPUT_PEAK_PNG}")
# Out:
# ✅ Figure saved to: /mnt/monadworld/projects/phd/monte_carlo_results/monte_carlo_peak_analysis.png

# %%
def plot_time_series(merged_files, output_path, max_ticks=5000, n_samples=5):
    """
    Plot time series for a sample of runs.
    """
    print("\n" + "="*60)
    print("TIME SERIES ANALYSIS")
    print("="*60)
    
    # Select representative runs
    n_files = len(merged_files)
    if n_files <= n_samples:
        sample_indices = list(range(n_files))
    else:
        step = n_files // n_samples
        sample_indices = list(range(0, n_files, step))[:n_samples]
    
    sample_files = [merged_files[i] for i in sample_indices]
    
    fig, ax = plt.subplots(figsize=(12, 6))
    colors = ['steelblue', 'coral', 'seagreen', 'purple', 'orange']
    
    for i, filepath in enumerate(sample_files):
        df_series = get_time_series(filepath)
        if not df_series.empty:
            df_plot = df_series[df_series['tick'] <= max_ticks]
            if not df_plot.empty:
                ax.plot(df_plot['tick'], df_plot['adults'], 
                       label=f'Run {i+1}', color=colors[i % len(colors)], 
                       linewidth=1.5, alpha=0.8)
    
    ax.set_xlabel('Tick')
    ax.set_ylabel('Adult Population')
    ax.set_title('Adult Population Dynamics (Sample Runs)')
    ax.legend()
    ax.grid(True, alpha=0.3)
    plt.tight_layout()
    plt.savefig(output_path, dpi=300, bbox_inches='tight')
    plt.show()
    print(f"✅ Time series figure saved to: {output_path}")

plot_time_series(merged_files, OUTPUT_TIMESERIES_PNG)
# Out:
# ============================================================
# TIME SERIES ANALYSIS
# ============================================================

# %% [markdown]
# ## 5. Report Generation
#
# Generate a complete text report with all findings.

# %%
def generate_report(df_results, stats, output_path):
    with open(output_path, 'w') as f:
        f.write("="*70 + "\n")
        f.write("MONTE CARLO SIMULATION - COMPLETE REPORT\n")
        f.write("="*70 + "\n\n")
        
        f.write(f"Total runs: {stats['n']}\n")
        f.write(f"Ticks per run: {TICKS_PER_RUN}\n\n")
        
        f.write("PEAK ADULT POPULATION\n")
        f.write("-"*40 + "\n")
        f.write(f"  Mean: {stats['peak_mean']:,.0f} ± {stats['peak_std']:,.0f}\n")
        f.write(f"  Median: {stats['peak_median']:,.0f}\n")
        f.write(f"  95% CI: [{stats['ci_low']:,.0f}, {stats['ci_high']:,.0f}]\n")
        f.write(f"  Min: {stats['peak_min']:,.0f}\n")
        f.write(f"  Max: {stats['peak_max']:,.0f}\n")
        f.write(f"  Range: {stats['peak_range']:,.0f}\n\n")
        
        f.write("PEAK TICK DISTRIBUTION\n")
        f.write("-"*40 + "\n")
        f.write(f"  Mean: {stats['tick_mean']:.0f}\n")
        f.write(f"  Median: {stats['tick_median']:.0f}\n")
        f.write(f"  Min: {stats['tick_min']:.0f}\n")
        f.write(f"  Max: {stats['tick_max']:.0f}\n\n")
        
        f.write("FINAL TICK ADULTS\n")
        f.write("-"*40 + "\n")
        f.write(f"  Mean: {stats['final_mean']:,.0f}\n")
        f.write(f"  Median: {stats['final_median']:,.0f}\n")
        f.write(f"  Runs with 0 final adults: {stats['zero_final']}\n\n")
        
        f.write("EARLY STAGE ADULTS (Tick 100)\n")
        f.write("-"*40 + "\n")
        f.write(f"  Mean: {stats['early_mean']:,.0f}\n")
        f.write(f"  Median: {stats['early_median']:,.0f}\n")
        f.write(f"  Runs with 0 early adults: {stats['zero_early']}\n\n")
        
        f.write("="*70 + "\n")
        f.write(f"Report generated: {pd.Timestamp.now()}\n")
        f.write(f"Results directory: {MONTE_CARLO_DIR}\n")
    
    print(f"✅ Complete report saved to: {output_path}")

generate_report(df_results, stats, OUTPUT_REPORT)

# %% [markdown]
# ## 6. Publication Summary
#
# Print a concise summary suitable for publications.

# %%
def print_publication_summary(stats):
    print("\n" + "="*70)
    print("MONTE CARLO SIMULATION - PUBLICATION SUMMARY")
    print("="*70)
    print(f"\n📊 Peak Adult Population (n={stats['n']} runs):")
    print(f"  Mean ± SD: {stats['peak_mean']:,.0f} ± {stats['peak_std']:,.0f}")
    print(f"  Median: {stats['peak_median']:,.0f}")
    print(f"  95% CI: [{stats['ci_low']:,.0f}, {stats['ci_high']:,.0f}]")
    print(f"  Range: {stats['peak_min']:,.0f} - {stats['peak_max']:,.0f}")
    print(f"\n📈 Peak Timing:")
    print(f"  Mean peak tick: {stats['tick_mean']:.0f}")
    print(f"  Median peak tick: {stats['tick_median']:.0f}")
    print(f"\n📉 Population Stages:")
    print(f"  Early (tick 100): {stats['early_mean']:,.0f} adults")
    print(f"  Peak: {stats['peak_mean']:,.0f} adults")
    print(f"  Final: {stats['final_mean']:,.0f} adults")

print_publication_summary(stats)

print("\n" + "="*60)
print("✅ MONTE CARLO ANALYSIS COMPLETE")
print("="*60)
print(f"\nResults saved to: {MONTE_CARLO_DIR}")
print(f"  - {os.path.basename(OUTPUT_CSV)} (peak data)")
print(f"  - {os.path.basename(OUTPUT_PEAK_PNG)} (visualizations)")
print(f"  - {os.path.basename(OUTPUT_TIMESERIES_PNG)} (population dynamics)")
print(f"  - {os.path.basename(OUTPUT_REPORT)} (full report)")
